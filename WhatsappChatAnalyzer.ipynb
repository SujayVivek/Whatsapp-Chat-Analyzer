# %%
pip install pandas
# Out:
# ...
#      ---------------------------------------- 10.6/10.6 MB 8.0 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 15.8/15.8 MB 8.2 MB/s eta 0:00:00
# ...
#      ------------------------------------- 502.5/502.5 kB 10.5 MB/s eta 0:00:00
# ...
#      -------------------------------------- 341.8/341.8 kB 7.1 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import re
import pandas as pd

# %%
f= open('WhatsApp Chat with Fever and headache 🤒 still will walk a 2.2.txt','r',encoding='utf-8')

# %%
data=f.read()

# %%
print(data)
# Out:
# 25/07/2023, 17:50 - Messages and calls are end-to-end encrypted. No one outside of this chat, not even WhatsApp, can read or listen to them. Tap to learn more.
# 25/07/2023, 17:50 - Rishika Maheswari 22BT30024 CQ created group "CQ Govs + Secy Unoff"
# 25/07/2023, 17:50 - Rishika Maheswari 22BT30024 CQ added you
# 25/07/2023, 17:50 - Rishika Maheswari 22BT30024 CQ changed the group name from "CQ Govs + Secy Unoff" to "CQ Unoff"
# 25/07/2023, 17:50 - Rishika Maheswari 22BT30024 CQ: Kon reh gaya secies mei
# 25/07/2023, 17:51 - Rishika Maheswari 22BT30024 CQ: Aur batao jaldi kya kya cheez ki treat baaki hai
# 25/07/2023, 17:51 - Manan Parakh 22AE10021 CQ: 18 log h
# 25/07/2023, 17:51 - Rishika Maheswari 22BT30024 CQ: Naam batao
# 25/07/2023, 17:51 - Manan Parakh 22AE10021 CQ: OnlySecretary me dekh
# 25/07/2023, 17:52 - Rishika Maheswari 22BT30024 CQ: Sunil promote hua hai?
# 25/07/2023, 17:52 - Lokesh Saran 22MT30020 CQ gyws: Haan
# ...

# %%
print(type(data))
# Out:
# <class 'str'>

# %% [markdown]
# Now we want to split the data into Dates and Message. We have to regularize-
# We can use a tool called regx101.com

# %%
pattern= "\d{1,2}/\d{1,2}/\d{2,4},\s\d{1,2}:\d{2}\s-\s"

# %%
messages=re.split(pattern,data)
messages
# Out:
# ['',
#  'Messages and calls are end-to-end encrypted. No one outside of this chat, not even WhatsApp, can read or listen to them. Tap to learn more.\n',
#  'Rishika Maheswari 22BT30024 CQ created group "CQ Govs + Secy Unoff"\n',
#  'Rishika Maheswari 22BT30024 CQ added you\n',
#  'Rishika Maheswari 22BT30024 CQ changed the group name from "CQ Govs + Secy Unoff" to "CQ Unoff"\n',
#  'Rishika Maheswari 22BT30024 CQ: Kon reh gaya secies mei\n',
#  'Rishika Maheswari 22BT30024 CQ: Aur batao jaldi kya kya cheez ki treat baaki hai\n',
#  'Manan Parakh 22AE10021 CQ: 18 log h\n',
#  'Rishika Maheswari 22BT30024 CQ: Naam batao\n',
#  'Manan Parakh 22AE10021 CQ: OnlySecretary me dekh\n',
#  'Rishika Maheswari 22BT30024 CQ: Sunil promote hua hai?\n',
#  'Lokesh Saran 22MT30020 CQ gyws: Haan\n',
#  'Rishika Maheswari 22BT30024 CQ added Ishita Mutneja 22GG10021 CQ\n',
#  'Rishika Maheswari 22BT30024 CQ added Karise Sunil Kumar 22EC10038 CQ\n',
#  'Rishika Maheswari 22BT30024 CQ: Rushikesh?\n',
# ...

# %%
dates=re.findall(pattern, data)
messages=messages[1:]

print(len(messages))
print(len(dates))
# Out:
# 2395
# 2395

# %%
df = pd.DataFrame({'user_message': messages, 'message_date': dates})
    # convert message_date type
df['message_date'] = pd.to_datetime(df['message_date'], format='%d/%m/%Y, %H:%M - ')

df.rename(columns={'message_date': 'date'}, inplace=True)
df.head()
# Out:
#                                         user_message                date
# 0  Messages and calls are end-to-end encrypted. N... 2023-07-25 17:50:00
# 1  Rishika Maheswari 22BT30024 CQ created group "... 2023-07-25 17:50:00
# 2         Rishika Maheswari 22BT30024 CQ added you\n 2023-07-25 17:50:00
# 3  Rishika Maheswari 22BT30024 CQ changed the gro... 2023-07-25 17:50:00
# 4  Rishika Maheswari 22BT30024 CQ: Kon reh gaya s... 2023-07-25 17:50:00

# %%
df.shape
# Out:
# (2395, 2)

# %% [markdown]
# Now lets convert the user_message into Name and Message
